# %% [markdown]
# <a href="https://colab.research.google.com/github/pingisu/AI4CCEE_Fall_2024/blob/main/in_class_activity/lecture3/Submissions/activity_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/235-Nov.csv')
print(df)
# Out:
#        owner-id network-id      date   time  utc-offset  start-ime  end-time  \
# 0        Q-Free     Q-Free  20211110  80900           0      80800     80900
# 1        Q-Free     Q-Free  20211110  80900           0      80800     80900
# 2        Q-Free     Q-Free  20211110  80900           0      80800     80900
# 3        Q-Free     Q-Free  20211110  80900           0      80800     80900
# 4        Q-Free     Q-Free  20211110  80900           0      80800     80900
# ...         ...        ...       ...    ...         ...        ...       ...
# 128775   Q-Free     Q-Free  20211109  50500           0      50400     50500
# 128776   Q-Free     Q-Free  20211109  50500           0      50400     50500
# 128777   Q-Free     Q-Free  20211109  50500           0      50400     50500
# 128778   Q-Free     Q-Free  20211109  50500           0      50400     50500
# 128779   Q-Free     Q-Free  20211109  50500           0      50400     50500
#
# ...

# %%
# prompt: convert units of specific column in database


# Assuming 'df' is your DataFrame and 'column_name' is the name of the column you want to convert
column_name = 'time'  # Replace with the actual column name
new_unit_column_name = 'time_in_hours'


# Define the conversion factor (e.g., convert from minutes to seconds)
conversion_factor = 60


if column_name in df.columns:
  # Create a new column with the converted values
  df[new_unit_column_name] = df[column_name] / conversion_factor
  print(df.head())  # Print the first few rows of the DataFrame with the new column
else:
  print(f"The column '{column_name}' does not exist in the DataFrame.")

column_name = 'date'  # Replace with the actual column name
new_unit_column_name = 'datetime'

conversion_factor = 20211102

if column_name in df.columns:
  # Create a new column with the converted values
  df[new_unit_column_name] = df[column_name] - conversion_factor
  print(df.head())  # Print the first few rows of the DataFrame with the new column
else:
  print(f"The column '{column_name}' does not exist in the DataFrame.")
# Out:
#   owner-id network-id      date   time  utc-offset  start-ime  end-time  \
# 0   Q-Free     Q-Free  20211110  80900           0      80800     80900
# 1   Q-Free     Q-Free  20211110  80900           0      80800     80900
# 2   Q-Free     Q-Free  20211110  80900           0      80800     80900
# 3   Q-Free     Q-Free  20211110  80900           0      80800     80900
# 4   Q-Free     Q-Free  20211110  80900           0      80800     80900
#
#      detector-id status  lane-id  ...  medium-class-count  large-class-count  \
# 0   DMDS20-WB EN     OK        1  ...                   0                  0
# 1   DMDS20-WB RL     OK        4  ...                   1                  0
# 2  DMDS20-WB RCL     OK        3  ...                   0                  0
# 3  DMDS20-WB LCL     OK        2  ...                   0                  0
# 4   DMDS20-WB LL     OK        1  ...                   0                  0
#
# ...

# %%
for date in df['date'].unique():
  avg_occupancy = df[df['date'] == date]['lane-occupancy'].mean()
  print(f"Average lane occupancy for {date}: {avg_occupancy}")
# Out:
# Average lane occupancy for 20211110: 4.478697674418605
# Average lane occupancy for 20211102: 4.229873193748157
# Average lane occupancy for 20211108: 4.288217149907465
# Average lane occupancy for 20211111: 2.362357414448669
# Average lane occupancy for 20211103: 1.8052338530066816
# Average lane occupancy for 20211109: 1.9666355140186915

# %%
# prompt: Visualize the total lane counts based on status, create a pie chart

import matplotlib.pyplot as plt

# Group the DataFrame by 'status' and count the number of lanes for each status
lane_counts_by_status = df.groupby('status')['lane-count'].count()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(lane_counts_by_status, labels=lane_counts_by_status.index, autopct='%1.1f%%', startangle=90)
plt.title('Total Lane Counts by Status')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each status
status_counts = df['status'].value_counts()

# Create a pie chart
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=90)

# Add a title to the chart
plt.title('Lane Counts by Status')

# Display the chart
plt.show()

# %%
# prompt: Create Scatter Plot of Lane Occupancy vs. Lane Count

plt.figure(figsize=(10, 6))
plt.scatter(df['lane-count'], df['lane-occupancy'], alpha=0.5)
plt.xlabel('Lane Count')
plt.ylabel('Lane Occupancy')
plt.title('Scatter Plot of Lane Occupancy vs. Lane Count')
plt.grid(True)
plt.show()
