# %%
# prompt: give a linux command to create a folder named act_2

# !mkdir act_2

# %%
# prompt: i want linux code to Navigate into act_2

# %cd act_2
# Out:
# /content/act_2

# %%
# prompt: i want linux code to Print path

# !pwd
# Out:
# /content/act_2

# %%
# prompt: i want linux code to create a file in the directory

# !touch new_file.txt

# %%
# !echo -e "#!/bin/bash\n\n# Print a message\necho 'Hello from the act_2 directory!'\n\n# List the files in the directory\nls" > myscript.sh

# %%
# !chmod +x myscript.sh

# %%
# !./myscript.sh
# Out:
# Hello from the act_2 directory!
# myscript.sh  new_file.txt  script.sh
