# %%
print("Hello Pyhton!")
# Out:
# Hello Pyhton!

# %%
name = "Percy Agyei-Essiful"
age = 25

about_1 = "Hello my name is " + name + " and I am " + str(age) + " years old!"

print(about_1)
# Out:
# Hello my name is Percy Agyei-Essiful and I am 25 years old!

# %%
# prompt:  i want python code to print a sentence in all caps

print(about_1.upper())
# Out:
# HELLO MY NAME IS PERCY AGYEI-ESSIFUL AND I AM 25 YEARS OLD!

# %%
print(about_1.lower())
# Out:
# hello my name is percy agyei-essiful and i am 25 years old!

# %%
hobby = "playing Fifa"

about_2 = "Hello my name is " + name + " and I love " + str(hobby) + "."

print(about_2)
# Out:
# Hello my name is Percy Agyei-Essiful and I love playing Fifa.
