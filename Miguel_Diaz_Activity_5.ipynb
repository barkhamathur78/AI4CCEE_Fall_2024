# %% [markdown]
# <a href="https://colab.research.google.com/github/miguel-source/AI4CCEE_Fall_2024/blob/main/Miguel_Diaz_Activity_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content

# %%
ls
# Out:
# sample_data/

# %%
# !git clone https://github.com/BarkhaM21/AI4CCEE_Fall_2024.git
# Out:
# Cloning into 'AI4CCEE_Fall_2024'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 20 (delta 2), reused 15 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (20/20), 846.92 KiB | 9.21 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
ls
# Out:
# AI4CCEE_Fall_2024/  sample_data/

# %%
cd AI4CCEE_Fall_2024/
# Out:
# /content/AI4CCEE_Fall_2024

# %%
ls -lh
# Out:
# total 12K
# drwxr-xr-x 3 root root 4.0K Sep  5 00:17 in_class_activity/
# drwxr-xr-x 2 root root 4.0K Sep  5 00:17 mini_project/
# -rw-r--r-- 1 root root   94 Sep  5 00:17 README.md

# %%
cd in_class_activity/
# Out:
# /content/AI4CCEE_Fall_2024/in_class_activity

# %%
ls -lh
# Out:
# total 8.0K
# drwxr-xr-x 2 root root 4.0K Sep  5 00:17 lecture2/
# -rw-r--r-- 1 root root   78 Sep  5 00:17 README.md

# %%
cd lecture2/
# Out:
# /content/AI4CCEE_Fall_2024/in_class_activity/lecture2

# %%
ls
# Out:
# cars.csv  Price.csv

# %%
# !sort -t, -k1,1 cars.csv > cars_sorted.csv
# !sort -t, -k1,1 Price.csv > price_sorted.csv

# !join -t, -1 1 -2 1 cars_sorted.csv price_sorted.csv > merged.csv

# %%
# !cat merged.csv
# Out:
# Streaming output truncated to the last 5000 lines.
# 85457,Toyota,Highlander XLE,2022,31000,Gasoline,295.0HP 3.5L V6 Cylinder Engine Gasoline Fuel,8-Speed A/T,Black,Gray,None reported,Yes,39218.443
# 85458,BMW,330 i,2017,74000,Gasoline,248.0HP 2.0L 4 Cylinder Engine Gasoline Fuel,A/T,Black,–,None reported,Yes,39218.443
# 85459,Ford,F-150 XLT,2019,67522,Gasoline,325.0HP 2.7L V6 Cylinder Engine Gasoline Fuel,A/T,Black,Red,None reported,Yes,39218.443
# 85460,Porsche,Panamera Turbo,2016,45617,Gasoline,520.0HP 4.8L 8 Cylinder Engine Gasoline Fuel,Transmission w/Dual Shift Mode,Black,Black,None reported,Yes,39218.443
# 85461,Land,Rover Range Rover Sport Supercharged HSE,2017,85000,Gasoline,340.0HP 3.0L V6 Cylinder Engine Gasoline Fuel,A/T,Black,Brown,None reported,Yes,39218.443
# 85462,MINI,Cooper S Base,2007,110022,Gasoline,172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel,6-Speed M/T,Yellow,Black,None reported,Yes,39218.443
# ...

# %%
# !git config --global user.name "miguel-source"
# !git config --global user.email "adi10136@iastate.edu"

# %%
cd ..
# Out:
# /content/AI4CCEE_Fall_2024/in_class_activity

# %%
ls
# Out:
# lecture2/  README.md

# %%
mkdir Miguel_Diaz

# %%
ls
# Out:
# lecture2/  Miguel_Diaz/  README.md

# %%
cd lecture2/
# Out:
# /content/AI4CCEE_Fall_2024/in_class_activity/lecture2

# %%
ls
# Out:
# cars.csv  cars_sorted.csv  merged.csv  Price.csv  price_sorted.csv

# %%
# prompt: move this file merged.csv to my folder Miguel_Diaz

# !mv merged.csv ../Miguel_Diaz/
# Out:
# mv: cannot move '/content/AI4CCEE_Fall_2024/in_class_activity/lecture2/merged.csv' to 'Miguel_Diaz/': Not a directory

# %%
# !mv merged.csv ../Miguel_Diaz/

# %%
cd ..
# Out:
# /content/AI4CCEE_Fall_2024/in_class_activity

# %%
ls
# Out:
# lecture2/  Miguel_Diaz/  README.md

# %%
cd Miguel_Diaz/
# Out:
# /content/AI4CCEE_Fall_2024/in_class_activity/Miguel_Diaz

# %%
ls
# Out:
# merged.csv

# %%
# !git add merged.csv
# !git commit -m "Added merged.csv"
# !git push origin main
# Out:
# [main 090aba7] Added merged.csv
#  1 file changed, 36184 insertions(+)
#  create mode 100644 in_class_activity/Miguel_Diaz/merged.csv
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !cd ..

# %%
ls
# Out:
# AI4CCEE_Fall_2024/  merged.csv

# %%
# !git add in_class_activity/Miguel_Diaz/merged.csv
# !git commit -m "Added merged.csv to Miguel_Diaz folder"
# !git push
# Out:
# ...
# fatal: pathspec 'in_class_activity/Miguel_Diaz/merged.csv' did not match any files
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	../lecture2/cars_sorted.csv
# 	../lecture2/price_sorted.csv
#
# nothing added to commit but untracked files present (use "git add" to track)
# fatal: could not read Username for 'https://github.com': No such device or address
